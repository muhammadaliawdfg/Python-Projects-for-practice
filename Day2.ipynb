# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadaliawdfg/Python-Projects-for-practice/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **what we learn Today**
# ** Data Types:** strings,integers,floats, and Booleans
# **Type Conversion**
# ** String Formatting**
# **Day 2 Project:** Personalized Greeting Propgram

# %%
name ="Hammad"

age =22

height =5.10

Is_single = True

print(type(name))
print(type(age))
print(type(height))
print(type(Is_single))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# **Type Conversion**

# %%
# string to integer

age = "17"

myAge = int(age)
print(myAge + 5)
# Out:
# 22

# %% [markdown]
# **String Foprmatting**

# %%
name = "Muhammad ali"
print("Hello. "+name+ "!")
print("Hello ! {}".format(name))
print(f"Hello {name}")
# Out:
# Hello. Muhammad ali!
# Hello ! Muhammad ali
# Hello Muhammad ali

# %% [markdown]
# **Personalized Greeting Project**

# %%
from datetime import datetime
name =input("What is your name?")
try:

  age = int(input("What is you age?"))
  current_year = datetime.now().year
  age = current_year-age
except ValueError:
  print("Invalid input Please enter a number")
  age =int(input("Enter you age again?"))
color =input("what is you favourit color")

print("\n --------------Personalized Greeting ------------")
print(f"Hello! {name}")
print(f"You are {age} years old and {color} is a beautiful color!")
print("You are now ready to start your python Adventure!")
print(f"You are cuurent age according to your birth is {age}!")
# Out:
# What is your name?Muhammad ali
# What is you age?25
# what is you favourit coloryellow
#
#  --------------Personalized Greeting ------------
# Hello! Muhammad ali
# You are 2001 years old and yellow is a beautiful color!
# You are now ready to start your python Adventure!
# You are cuurent age according to your birth is 2001!

# %% [markdown]
# **what are the IF-Else Statements?**
# **Comparison** Operators
# **Logical** Operators
# **Nested If-Else** Statements
# **Project: Number Comparison Tool**

# %%
#  what are IF_else Statements
number = 5
if number > 5:
  print("The number is Greater than 5")
elif number == 5:
  print("Equal to 5")
else:
  print("The numebr is less than 5")
# Out:
# Equal to five

# %% [markdown]
# **Comparison Operators  & Logical Operators**

# %%
# Comparison Operators
# == equals to
# != not equal
# > greater than
# < less than
# Logical Operators
# and or nor
a=7
b=5

if a>5 or b>7:
  print("Both condition True")
else:
  print("Condition is false")
# Out:
# Both condition True

# %% [markdown]
# **Nested IF_ELSE statements**

# %%
number = 5
if number > 5:
  print("The number is Greater than 5")
elif number == 5:
  print("Equal to 5")
else:
  print("The numebr is less than 5")
# Out:
# Equal to 5

# %% [markdown]
# **Number Comparison**

# %%
num1=float(input("Enter you first Number "))
num2=float(input("Enter you second Number "))

if num1 == num2:
  print(f"{num1} and {num2} is equal")
elif num1 > num2:
  print(f"{num1} is greater than {num2}")
else:
  print(f"{num2} is greater than {num1}")

if num1 == 0 or num2 == 0:
  print("\n at least you enter one number is zero")
else:
  print("Your entered both number are non-zeros")
# Out:
# Enter you first Number 10000
# Enter you second Number 900
# 10000.0 is greater than 900.0
# Your entered both number are non-zeros

# %% [markdown]
# 1.   what are Loop
# 2.   For loops
# 3.   While Loops
# 4.   Using time.sleep() for Dealys
# 5.   Project: Countdown timer

# %%
# for loop which repeat a set number of times and the while repeat until a condition become false
# syntax for loop
for variable in range(start, stop , step):
# start = starting value and stop is end value which does not include in range and step is how much increment by and the default is one
# synatx while loop
while condition:
  # code to repeat
# Out:
#   File "/tmp/ipython-input-2619496098.py", line 6
#
#     ^
# SyntaxError: incomplete input

# %%
for i in range(5,0,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count = 7
while count > 0:
  print(count)
  count -=2
# Out:
# 7
# 5
# 3
# 1

# %%
# time.sleep is using for delays some time we want to pause our program for a moment between iteratin then use this
import time
for i in range(3,0,-1):
 print(i)
 time.sleep(2)
print("Happy Birthday")
# Out:
# 3
# 2
# 1
# Happy Birthday

# %% [markdown]
# **Countdown Timer**

# %%
import time

start = int(input("Enter the number to start the countdown from: "))
speed = float(input("Enter countdown speed you want "))

half_point =start//2
print("\n----- Countdown Start --------")
while start>0:
  print(start)
  time.sleep(speed)
  start-=1

  if start == half_point:
    print("Your half countdown is complete")
print("--------Countdown end---------")
# Out:
# Enter the number to start the countdown from: 12
# Enter countdown speed you want 1
#
# ----- Countdown Start --------
# 12
# 11
# 10
# 9
# 8
# 7
# Your half countdown is complete
# 6
# 5
# 4
# 3
# 2
# 1
# --------Countdown end---------

# %%
import re

user_input = input("Enter something: ")

match = re.search(r'\d+', user_input)

if match:
    print("First number found:", int(match.group()))
else:
    print("No number found.")
# Out:
# Enter something: -123abc
# First number found: 123

# %% [markdown]
# 1.   defining and calling functions
# 2.   function parameters and arguments
# 3.   Reurn Statements
# 4.   Basic Math Quiz Game

# %%
# synatx
# def function_name():def function
  # print("hello") inetrnalk poart
# function_name() call function
# Out:
# hello

# %% [markdown]
# **using Parameters and Arguments**

# %%
def greet_user(name):
  print(f"Hello! {name} welcome to python course")
greet_user("Ahmed")
# Out:
# Hello! Ahmed welcome to python course

# %%
def add(a,b):

  print(f"The sum of  a and b is {a+b}")
  add(4,5)

# %%
# return statement
def multiply(a,b):
  return a*b
result = multiply(5,4)
print("The sum of  a and b is :",result)
# Out:
# The sum of  a and b is : 20

# %%
# Basic Math quiz game
import random

def generate_question():
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)
    operator = random.choice(['+', '-', '*'])

    if operator == '+':
        answer = num1 + num2
    elif operator == '-':
        answer = num1 - num2
    else:
        answer = num1 * num2

    return f"{num1} {operator} {num2}", answer


def math_quiz():
    score = 0
    rounds = 5

    print("\nWelcome to the Math Quiz!")
    print("You will be presented with problems, and you need to provide the correct answer.")

    for i in range(rounds):
        question, correct_answer = generate_question()
        print(f"\nQuestion {i+1}: {question}")

        try:
            user_answer = int(input("Your answer: "))
        except ValueError:
            print("Invalid input! Skipping question.")
            continue

        if user_answer == correct_answer:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer was {correct_answer}")

    print("\n----- Game Over! -----")
    print(f"Your final score is: {score} / {rounds}")

    if score == rounds:
        print("Excellent! You got all questions correct!")
    elif score >= rounds // 2:
        print("Good job! You did well.")
    else:
        print("Keep practicing! You can do better next time.")


# Call the function once
math_quiz()
# Out:
# Welcome to the Math Quiz!
# You will be presented with problems, and you need to provide the correct answer.
#
# Question 1: 5 * 3
# Your answer: 15
# Correct!
#
# Question 2: 4 + 2
# Your answer: 6
# Correct!
#
# Question 3: 2 - 10
# Your answer: -8
# Correct!
#
# Question 4: 9 + 3
# Your answer: 12
# Correct!
#
# Question 5: 8 - 3
# Your answer: 5
# Correct!
#
# ----- Game Over! -----
# Your final score is: 5 / 5
# Excellent! You got all questions correct!
