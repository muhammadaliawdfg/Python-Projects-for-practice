# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadaliawdfg/Python-Projects-for-practice/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Understand Return Values in Functions
# 2. Using Functions to perfrom Calculations
# 3. How to Return Multiple Values
# 4. Best Practices for Return Values
# Project: Temprature Converter

# %%
# understand Return Values in Functions
def function_name():
  # code
  return value

# %%
def add(a,b):
  return a+b
result =add(10,20)
print(result)
# Out:
# 30

# %% [markdown]
# Use functions to perform Calculations

# %%
def reactangle_area(width, height):
  return width * height
area = reactangle_area(10,20)
print(area)
# Out:
# 200

# %%
# return multiple values using tuples
def math_operation(a,b):
  addition = a+b
  subtraction = a-b
  multiplication = a*b
  division = a/b
  return addition, subtraction, multiplication, division
divide,add,sub,mul = math_operation(10,20)
print(divide)
# Out:
# 30

# %%
# Temprature Convertor
#  define conversion functions
def celsius_to_fahrenheit(celsius):
  return (celsius *9/5) + 32
def celsius_to_kelvin(celsius):
  return celsius + 273.15
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit - 32) * 5/9
def fahrenheit_to_kelvin(fahrenheit):
  return (fahrenheit - 32) * 5/9 + 273.15
def kelvin_to_celsius(kelvin):
  return kelvin - 273.15
def kelvin_to_fahrenheit(kelvin):
  return (kelvin - 273.15) * 9/5 + 32
def main_menu():
  print("\n-------Temperature Converter Menu:--------\n")
  print("1. Celsius to Fahrenheit & Kelvin")
  print("2. Fahrenheit to Celsius & Kelvin")
  print("3. Kelvin to Celsius & Fahrenheit")
  print("4. Exit")

while True:
  main_menu()
  choice = input("Enter your choice (1-4): ")
  if choice == "1":
    celsius = float(input("Enter temperature in Celsius: "))
    print(f"Fahrenheit: {celsius_to_fahrenheit(celsius):.2f}")
    print(f"Kelvin: {celsius_to_kelvin(celsius):.2f}")
  elif choice == "2":
    fahrenheit = float(input("Enter temprature in Fahrehheit: "))
    print(f"Celsius: {fahrenheit_to_celsius (fahrenheit):.2f}")
    print(f"Kelvin: {fahrenheit_to_kelvin(fahrenheit):.2f}")
  elif choice == '3':
    kelvin = float(input("Enter temperature in Kelvin: "))
    print(f"Celsius: {kelvin_to_celsius(kelvin):.2f}")
    print(f"Fahrenheit: {kelvin_to_fahrenheit(kelvin):.2f}")
  elif choice == '4':
    print("Exiting the program. Goodbye!")
    break
  else:
    print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# -------Temperature Converter Menu:--------
#
# 1. Celsius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celsius & Kelvin
# 3. Kelvin to Celsius & Fahrenheit
# 4. Exit
# Enter your choice (1-4): 2
# Enter temprature in Fahrehheit: 60
# Celsius: 15.56
# Kelvin: 288.71
#
# -------Temperature Converter Menu:--------
#
# 1. Celsius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celsius & Kelvin
# 3. Kelvin to Celsius & Fahrenheit
# 4. Exit
# Enter your choice (1-4): 4
# Exiting the program. Goodbye!
